# %%
import pandas as pd

# %%
df = pd.read_csv("Grocery_Database.csv")
df
# Out:
#                                                     name    store  \
# 0      Stonyfield Organic Whole Milk Strawberry Beet ...   Target
# 1      Stonyfield Organic Whole Milk Pear Spinach Man...   Target
# 2      Once Upon a Farm Organic Mama Blueberry Fruit ...   Target
# 3      Once Upon a Farm Organic Strawberry Kids&#39; ...   Target
# 4      Horizon Organic Growing Years Strawberry Kids&...   Target
# ...                                                  ...      ...
# 26245     Sam's Choice Creamy Honey Almond Butter, 12 oz  Walmart
# 26246  Nutella and Go Snack Packs, Hazelnut Spread & ...  Walmart
# 26247    Sabra Dark Chocolate Dessert Dip & Spread, 8 oz  Walmart
# 26248  MaraNatha, No Stir Peanut Butter, 1.15 oz Packets  Walmart
# 26249  Great Value No Stir Creamy Natural Peanut Butt...  Walmart
#
#              category             brand      FPro  FPro_class  price  \
# 0           baby-food        Stonyfield  0.815250         3.0   5.29
# ...

# %%
grouped = df[['store', 'FPro', 'price', 'price percal', 'Protein', 'Total Fat', 'Carbohydrate', 'Sodium', 'Cholesterol']].groupby("store").mean()
grouped
# Out:
#                 FPro     price  price percal    Protein  Total Fat  \
# store
# Target      0.800506  4.802936      0.014808  10.147212  14.369421
# Walmart     0.764341  3.555103      0.006830   8.304587  12.666542
# WholeFoods  0.658023  5.708006      0.067899   8.143150  12.405901
#
#             Carbohydrate     Sodium  Cholesterol
# store
# Target         38.738111   0.511358     0.038647
# Walmart        35.225758  63.289570     0.043340
# WholeFoods     33.295888   0.411356     0.017130
